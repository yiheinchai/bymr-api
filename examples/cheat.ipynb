# %%
import sys

sys.path.insert(0, '../')

import time
from bymr_api import BYMRClient, UserData
import sys
import os

BEARER_TOKEN = os.getenv('BYMR_BEARER_TOKEN')

# %%
import importlib
import bymr_api.models
importlib.reload(bymr_api)
# Out:
# <module 'bymr_api' from '/Users/yihein.chai/Documents/learn/bymr-api/examples/../bymr_api/__init__.py'>

# %%
client = BYMRClient(
    bearer_token=BEARER_TOKEN,
    verify_ssl=False,
    state_file="game_state.json",
    user_file="user.json",
)
# Out:
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
client.set_resources(r1=0, r2=0, r3=0, r4=0)
# Out:
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
client.buy_starter_kit('20444959350261')
# Out:
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# {'error': 0,
#  'basesaveid': 267660,
#  'baseid': '20444959350261',
#  'homebaseid': '14926',
#  'userid': 1008523,
#  'saveuserid': 1008523,
#  'attackid': 0,
#  'id': 1767244659,
#  'baseid_inferno': 0,
#  'wmid': 0,
#  'type': 'outpost',
#  'createtime': 1767243635,
#  'savetime': 1767245388,
#  'seed': 0,
#  'bookmarked': 0,
#  'fan': 0,
#  'emailshared': 1,
#  'unreadmessages': 0,
#  'giftsentcount': 0,
#  'canattack': False,
#  'fbid': '100002268912813',
#  'fortifycellid': 0,
#  'name': 'josesteve',
#  'level': 1,
#  'catapult': 0,
#  'flinger': 4,
#  'destroyed': 1,
#  'damage': 0,
#  'locked': 0,
#  'points': '41650691',
#  'basevalue': '7282364',
#  'tutorialstage': 205,
#  'protected': 1767286835,
#  'lastupdate': 0,
#  'usemap': 1,
#  'credits': 3207,
#  'champion': 'null',
#  'empiredestroyed': 0,
#  'worldid': '2132bac8-cfc3-462d-b9b0-33171c0fc650',
#  'event_score': 0,
#  'chatenabled': 0,
#  'relationship': 0,
#  'timeplayed': 0,
#  'version': 128,
#  'clienttime': 0,
#  'baseseed': 4520,
#  'healtime': 0,
#  'empirevalue': 41526414,
#  'basename': 'basename',
#  'over': 1,
#  'protect': 0,
#  'purchasecomplete': 0,
#  'cantmovetill': None,
#  'attacks': [],
#  'buildingkeydata': {},
#  'buildinghealthdata': {},
#  'buildingdata': {'0': {'X': 0, 'Y': -50, 't': 112, 'id': 0, 'fort': 4},
#   '2': {'X': 130, 'Y': 60, 'l': 5, 't': 17, 'id': 2},
#   '3': {'X': 130, 'Y': 40, 'l': 5, 't': 17, 'id': 3},
#   '4': {'X': 130, 'Y': 20, 'l': 5, 't': 17, 'id': 4},
#   '5': {'X': 130, 'Y': 0, 'l': 5, 't': 17, 'id': 5},
#   '6': {'X': 130, 'Y': -20, 'l': 5, 't': 17, 'id': 6},
#   '7': {'X': 150, 'Y': 60, 'l': 5, 't': 17, 'id': 7},
#   '8': {'X': 170, 'Y': 60, 'l': 5, 't': 17, 'id': 8},
#   '9': {'X': 190, 'Y': 60, 'l': 5, 't': 17, 'id': 9},
#   '10': {'X': 150, 'Y': 80, 'l': 5, 't': 115, 'id': 10, 'fort': 3},
#   '12': {'X': 130, 'Y': 100, 'l': 5, 't': 17, 'id': 12},
#   '13': {'X': 130, 'Y': 120, 'l': 5, 't': 17, 'id': 13},
#   '14': {'X': 210, 'Y': 60, 'l': 5, 't': 17, 'id': 14},
#   '15': {'X': 130, 'Y': 140, 'l': 5, 't': 17, 'id': 15},
#   '16': {'X': 230, 'Y': 60, 'l': 5, 't': 17, 'id': 16},
#   '17': {'X': 230, 'Y': 80, 'l': 5, 't': 17, 'id': 17},
#   '18': {'X': 230, 'Y': 100, 'l': 5, 't': 17, 'id': 18},
#   '19': {'X': 230, 'Y': 120, 'l': 5, 't': 17, 'id': 19},
#   '20': {'X': 230, 'Y': 140, 'l': 5, 't': 17, 'id': 20},
#   '21': {'X': 290, 'Y': 60, 'l': 5, 't': 17, 'id': 21},
#   '22': {'X': 210, 'Y': 150, 'l': 5, 't': 17, 'id': 22},
#   '23': {'X': 190, 'Y': 150, 'l': 5, 't': 17, 'id': 23},
#   '24': {'X': 170, 'Y': 150, 'l': 5, 't': 17, 'id': 24},
#   '25': {'X': 150, 'Y': 150, 'l': 5, 't': 17, 'id': 25},
#   '26': {'X': 310, 'Y': 50, 'l': 5, 't': 17, 'id': 26},
#   '27': {'X': -20, 'Y': -50, 'l': 5, 't': 17, 'id': 27},
#   '28': {'X': -20, 'Y': -30, 'l': 5, 't': 17, 'id': 28},
#   '29': {'X': -20, 'Y': -10, 'l': 5, 't': 17, 'id': 29},
#   '30': {'X': -20, 'Y': 10, 'l': 5, 't': 17, 'id': 30},
#   '31': {'X': -20, 'Y': 30, 'l': 5, 't': 17, 'id': 31},
#   '32': {'X': -40, 'Y': -50, 'l': 5, 't': 17, 'id': 32},
#   '33': {'X': -60, 'Y': -50, 'l': 5, 't': 17, 'id': 33},
#   '34': {'X': -80, 'Y': -50, 'l': 5, 't': 17, 'id': 34},
#   '35': {'X': -100, 'Y': -50, 'l': 5, 't': 17, 'id': 35},
#   '36': {'X': -120, 'Y': -50, 'l': 5, 't': 17, 'id': 36},
#   '37': {'X': -120, 'Y': -70, 'l': 5, 't': 17, 'id': 37},
#   '38': {'X': -120, 'Y': -90, 'l': 5, 't': 17, 'id': 38},
#   '39': {'X': -120, 'Y': -110, 'l': 5, 't': 17, 'id': 39},
#   '40': {'X': -120, 'Y': -130, 'l': 5, 't': 17, 'id': 40},
#   '41': {'X': -100, 'Y': -120, 'l': 5, 't': 115, 'id': 41, 'fort': 3},
#   '42': {'X': -200, 'Y': -20, 'l': 5, 't': 17, 'id': 42},
#   '43': {'X': -100, 'Y': -140, 'l': 5, 't': 17, 'id': 43},
#   '44': {'X': -80, 'Y': -140, 'l': 5, 't': 17, 'id': 44},
#   '45': {'X': -60, 'Y': -140, 'l': 5, 't': 17, 'id': 45},
#   '46': {'X': -40, 'Y': -140, 'l': 5, 't': 17, 'id': 46},
#   '47': {'X': -200, 'Y': 0, 'l': 5, 't': 17, 'id': 47},
#   '48': {'X': -20, 'Y': -130, 'l': 5, 't': 17, 'id': 48},
#   '49': {'X': -20, 'Y': -110, 'l': 5, 't': 17, 'id': 49},
#   '50': {'X': -20, 'Y': -90, 'l': 5, 't': 17, 'id': 50},
#   '51': {'X': -20, 'Y': -70, 't': 117, 'id': 51},
#   '52': {'X': 60, 'Y': 80, 'l': 3, 't': 23, 'id': 52, 'fort': 2},
#   '53': {'X': 0, 'Y': -120, 'l': 3, 't': 118, 'id': 53, 'fort': 2},
#   '54': {'X': 40, 'Y': 100, 'l': 5, 't': 17, 'id': 54},
#   '55': {'X': 40, 'Y': 80, 't': 24, 'id': 55},
#   '56': {'X': 70, 'Y': -70, 't': 24, 'id': 56},
#   '57': {'X': 20, 'Y': 80, 't': 117, 'id': 57},
#   '58': {'X': 90, 'Y': -70, 't': 117, 'id': 58},
#   '59': {'X': -430, 'Y': 60, 'l': 6, 't': 15, 'id': 59},
#   '60': {'X': 130, 'Y': -130, 'l': 3, 't': 22, 'id': 60},
#   '61': {'X': -90, 'Y': 70, 'l': 3, 't': 22, 'id': 61},
#   '62': {'X': -90, 'Y': -30, 'l': 3, 't': 25, 'id': 62, 'fort': 2},
#   '63': {'X': -20, 'Y': 50, 't': 117, 'id': 63},
#   '64': {'X': -40, 'Y': 40, 't': 24, 'id': 64},
#   '65': {'X': -60, 'Y': 40, 't': 24, 'id': 65},
#   '66': {'X': 130, 'Y': -40, 't': 24, 'id': 66},
#   '67': {'X': 150, 'Y': -30, 't': 24, 'id': 67},
#   '69': {'X': 170, 'Y': -30, 't': 24, 'id': 69},
#   '70': {'X': 70, 'Y': -90, 'l': 5, 't': 17, 'id': 70},
#   '71': {'X': 70, 'Y': -110, 'l': 5, 't': 17, 'id': 71},
#   '72': {'X': 70, 'Y': -130, 'l': 5, 't': 17, 'id': 72},
#   '73': {'X': 70, 'Y': -150, 'l': 5, 't': 17, 'id': 73},
#   '74': {'X': 50, 'Y': -140, 'l': 5, 't': 17, 'id': 74},
#   '75': {'X': 30, 'Y': -140, 'l': 5, 't': 17, 'id': 75},
#   '76': {'X': 70, 'Y': -170, 'l': 5, 't': 17, 'id': 76},
#   '77': {'X': 70, 'Y': -190, 'l': 5, 't': 17, 'id': 77},
#   '78': {'X': 70, 'Y': -210, 'l': 5, 't': 17, 'id': 78},
#   '79': {'X': 110, 'Y': -220, 'l': 8, 't': 21, 'id': 79, 'fort': 1},
#   '80': {'X': 110, 'Y': -150, 'l': 5, 't': 17, 'id': 80},
#   '81': {'X': 130, 'Y': -150, 'l': 5, 't': 17, 'id': 81},
#   '82': {'X': 150, 'Y': -150, 'l': 5, 't': 17, 'id': 82},
#   '83': {'X': 110, 'Y': -130, 'l': 5, 't': 17, 'id': 83},
#   '84': {'X': 40, 'Y': 120, 'l': 5, 't': 17, 'id': 84},
#   '85': {'X': 40, 'Y': 140, 'l': 5, 't': 17, 'id': 85},
#   '86': {'X': 60, 'Y': 150, 'l': 5, 't': 17, 'id': 86},
#   '87': {'X': 80, 'Y': 150, 'l': 5, 't': 17, 'id': 87},
#   '88': {'X': 40, 'Y': 160, 'l': 5, 't': 17, 'id': 88},
#   '89': {'X': 40, 'Y': 180, 'l': 5, 't': 17, 'id': 89},
#   '90': {'X': 40, 'Y': 200, 'l': 5, 't': 17, 'id': 90},
#   '91': {'X': 40, 'Y': 220, 'l': 5, 't': 17, 'id': 91},
#   '92': {'X': 0, 'Y': -210, 'l': 8, 't': 20, 'id': 92, 'fort': 1},
#   '93': {'X': 60, 'Y': 170, 'l': 8, 't': 20, 'id': 93, 'fort': 1},
#   '94': {'X': 250, 'Y': 60, 'l': 5, 't': 17, 'id': 94},
#   '95': {'X': 270, 'Y': 60, 'l': 5, 't': 17, 'id': 95},
#   '96': {'X': 220, 'Y': 20, 'l': 5, 't': 17, 'id': 96},
#   '97': {'X': 220, 'Y': 40, 't': 24, 'id': 97},
#   '98': {'X': -140, 'Y': -50, 'l': 5, 't': 17, 'id': 98},
#   '99': {'X': -160, 'Y': -50, 'l': 5, 't': 17, 'id': 99},
#   '100': {'X': -110, 'Y': -10, 'l': 5, 't': 17, 'id': 100},
#   '101': {'X': -110, 'Y': -30, 't': 24, 'id': 101},
#   '102': {'X': 220, 'Y': 0, 'l': 5, 't': 17, 'id': 102},
#   '103': {'X': 220, 'Y': -20, 'l': 5, 't': 17, 'id': 103},
#   '104': {'X': 220, 'Y': -40, 'l': 5, 't': 17, 'id': 104},
#   '105': {'X': 220, 'Y': -110, 'l': 8, 't': 21, 'id': 105, 'fort': 1},
#   '106': {'X': -160, 'Y': 70, 'l': 8, 't': 21, 'id': 106, 'fort': 1},
#   '107': {'X': -110, 'Y': 10, 'l': 5, 't': 17, 'id': 107},
#   '108': {'X': -110, 'Y': 30, 'l': 5, 't': 17, 'id': 108},
#   '109': {'X': -110, 'Y': 50, 'l': 5, 't': 17, 'id': 109},
#   '110': {'X': -130, 'Y': 50, 'l': 5, 't': 17, 'id': 110},
#   '111': {'X': -150, 'Y': 50, 'l': 5, 't': 17, 'id': 111},
#   '112': {'X': -170, 'Y': 50, 'l': 5, 't': 17, 'id': 112},
#   '113': {'X': -180, 'Y': -20, 'l': 3, 't': 23, 'id': 113, 'fort': 2},
#   '114': {'X': 240, 'Y': -40, 'l': 5, 't': 17, 'id': 114},
#   '115': {'X': 260, 'Y': -40, 'l': 5, 't': 17, 'id': 115},
#   '116': {'X': 280, 'Y': -40, 'l': 5, 't': 17, 'id': 116},
#   '117': {'X': 0, 'Y': 140, 'l': 5, 't': 17, 'id': 117},
#   '118': {'X': 0, 'Y': 160, 'l': 5, 't': 17, 'id': 118},
#   '119': {'X': -20, 'Y': 160, 'l': 5, 't': 17, 'id': 119},
#   '120': {'X': -40, 'Y': 160, 'l': 5, 't': 17, 'id': 120},
#   '121': {'X': -190, 'Y': -120, 'l': 8, 't': 20, 'id': 121, 'fort': 1},
#   '122': {'X': 0, 'Y': -140, 't': 24, 'id': 122},
#   '123': {'X': -20, 'Y': -150, 't': 24, 'id': 123},
#   '124': {'X': 240, 'Y': -20, 'l': 8, 't': 20, 'id': 124, 'fort': 1},
#   '125': {'X': -30, 'Y': 180, 'l': 8, 't': 21, 'id': 125, 'fort': 1},
#   '126': {'X': 300, 'Y': -40, 'l': 5, 't': 17, 'id': 126},
#   '127': {'X': 290, 'Y': -60, 'l': 5, 't': 17, 'id': 127},
#   '128': {'X': 290, 'Y': -80, 'l': 5, 't': 17, 'id': 128},
#   '129': {'X': -180, 'Y': 70, 'l': 5, 't': 17, 'id': 129},
#   '130': {'X': -190, 'Y': 50, 'l': 5, 't': 17, 'id': 130},
#   '131': {'X': 20, 'Y': 160, 't': 24, 'id': 131},
#   '132': {'X': 20, 'Y': 140, 't': 24, 'id': 132},
#   '133': {'X': 90, 'Y': -150, 't': 24, 'id': 133},
#   '134': {'X': 90, 'Y': -130, 't': 24, 'id': 134},
#   '135': {'X': 310, 'Y': 10, 'l': 5, 't': 17, 'id': 135},
#   '136': {'X': 310, 'Y': 30, 'l': 5, 't': 17, 'id': 136},
#   '137': {'X': -180, 'Y': -50, 'l': 5, 't': 17, 'id': 137},
#   '138': {'X': -180, 'Y': 90, 'l': 5, 't': 17, 'id': 138},
#   '139': {'X': -200, 'Y': -40, 'l': 5, 't': 17, 'id': 139},
#   '140': {'X': -200, 'Y': 20, 't': 24, 'id': 140},
#   '143': {'X': -110, 'Y': 140, 't': 24, 'id': 143},
#   '144': {'X': 190, 'Y': -150, 't': 24, 'id': 144},
#   '145': {'X': 220, 'Y': -130, 't': 24, 'id': 145},
#   '146': {'X': 0, 'Y': 80, 't': 24, 'id': 146},
#   '147': {'X': 0, 'Y': 100, 't': 24, 'id': 147},
#   '148': {'X': 110, 'Y': -70, 't': 24, 'id': 148},
#   '149': {'X': 190, 'Y': -30, 't': 24, 'id': 149},
#   '150': {'X': 100, 'Y': 150, 't': 24, 'id': 150},
#   '151': {'X': -90, 'Y': 160, 't': 24, 'id': 151},
#   '152': {'X': 150, 'Y': -10, 'l': 3, 't': 25, 'id': 152, 'fort': 2},
#   '153': {'X': -110, 'Y': -360, 't': 9, 'id': 153},
#   '154': {'X': 30,
#    'Y': -370,
#    'l': 3,
#    't': 13,
#    'id': 154,
#    'rCP': 2460,
#    'rIP': 'C12',
#    'rPS': 1},
#   '155': {'X': 250, 'Y': -180, 'l': 8, 't': 1, 'id': 155, 'rCP': 18},
#   '156': {'X': 180, 'Y': -220, 'l': 8, 't': 2, 'id': 156, 'rCP': 4},
#   '157': {'X': 225, 'Y': -335, 'l': 8, 't': 3, 'id': 157, 'rCP': 3},
#   '158': {'X': 365, 'Y': 35, 'l': 8, 't': 4, 'id': 158, 'rCP': 15},
#   '159': {'X': 55,
#    'Y': 290,
#    'l': 3,
#    't': 13,
#    'id': 159,
#    'rCP': 2461,
#    'rIP': 'C12',
#    'rPS': 1},
#   '160': {'X': 230, 'Y': 270, 'l': 4, 't': 5, 'id': 160},
#   '161': {'X': -250, 'Y': 80, 'l': 8, 't': 1, 'id': 161, 'rCP': 12},
#   '162': {'X': -180, 'Y': 140, 'l': 8, 't': 2, 'id': 162, 'rCP': 13},
#   '163': {'X': -90, 'Y': 300, 'l': 8, 't': 3, 'id': 163, 'rCP': 6},
#   '164': {'X': -225, 'Y': 255, 'l': 8, 't': 4, 'id': 164, 'rCP': 10},
#   '165': {'X': 355, 'Y': -125, 't': 16, 'id': 165, 'mq': [['C12', 10]]},
#   '167': {'X': -400, 'Y': -110, 't': 10, 'id': 167},
#   '168': {'X': -260, 'Y': -150, 'l': 8, 't': 1, 'id': 168, 'rCP': 18},
#   '169': {'X': -190,
#    'Y': -190,
#    'l': 8,
#    't': 2,
#    'cU': 171665,
#    'id': 169,
#    'rCP': 7},
#   '170': {'X': -350, 'Y': -260, 'l': 8, 't': 3, 'id': 170, 'rCP': 3},
#   '171': {'X': -240, 'Y': -340, 'l': 8, 't': 4, 'id': 171, 'rCP': 2},
#   '172': {'X': 180, 'Y': 170, 'l': 8, 't': 2, 'id': 172, 'rCP': 5},
#   '173': {'X': 250, 'Y': 110, 'l': 8, 't': 1, 'id': 173, 'rCP': 16},
#   '174': {'X': 350, 'Y': 155, 'l': 8, 't': 3, 'id': 174, 'rCP': 18},
#   '175': {'X': 345, 'Y': -255, 'l': 8, 't': 4, 'id': 175, 'rCP': 6},
#   '176': {'X': 130, 'Y': 80, 't': 117, 'id': 176}},
#  'researchdata': {},
#  'stats': {'mg': 4,
#   'mp': 7,
#   'mob': 0,
#   'mobg': 0,
#   'moga': 0,
#   'other': {'s': 1,
#    'pi': 1767236990,
#    'mrl': 2,
#    'mmscore': 0,
#    'renewal': 0,
#    'lastTime': 1767238266,
#    'wmi_wave': 0,
#    'lastLevel': 2,
#    'wmi2_wave': 100,
#    'expiration': 0,
#    'lasttdpopup': 100,
#    'changedToMR2': 2,
#    'lastKOTHTier': 5,
#    'lastKOTHScore': -1619276800,
#    'lastWmi1EventEnd': 1765926000,
#    'lastWmi2EventEnd': 1768604400,
#    'infernoUpgradeShown': 1},
#   'inferno': 0,
#   'updateid': 0,
#   'popupdata': {'lastDialog': 0, 'popupStates': {}},
#   'achievements': {'c': {'1': 1, '2': 1, '3': 1, '6': 1, '15': 1, '22': 1},
#    's': {'map2': 1,
#     'thlevel': 10,
#     'wm2hall': 0,
#     'alliance': 0,
#     'hugerage': 0,
#     'stockpile': 1,
#     'wmoutpost': 0,
#     'heavytraps': 0,
#     'starterkit': 0,
#     'blocksbuilt': 0,
#     'DESCENT_LEVEL': 0,
#     'playeroutpost': 0,
#     'unlock_monster': 0,
#     'upgrade_champ1': 0,
#     'upgrade_champ2': 0,
#     'upgrade_champ3': 1,
#     'UNDERHALL_LEVEL': 0,
#     'monstersblended': 0,
#     'INFERNO_QUESTS_COMPLETED': 0}},
#   'updateid_mr2': 2,
#   'updateid_mr3': 0},
#  'academy': {'C1': {'level': 1},
#   'C2': {'level': 1},
#   'C3': {'level': 1},
#   'C4': {'level': 1},
#   'C5': {'level': 1},
#   'C6': {'level': 1},
#   'C7': {'level': 1},
#   'C8': {'level': 1},
#   'C9': {'level': 1},
#   'C10': {'level': 1},
#   'C11': {'level': 1},
#   'C12': {'level': 1},
#   'C13': {'level': 1},
#   'C14': {'level': 6},
#   'C15': {'level': 1},
#   'C16': {'level': 6},
#   'C17': {'level': 1},
#   'C18': {'level': 1},
#   'C19': {'level': 1},
#   'IC1': {'level': 1},
#   'IC2': {'level': 1},
#   'IC3': {'level': 1},
#   'IC4': {'level': 1},
#   'IC5': {'level': 1},
#   'IC6': {'level': 1},
#   'IC7': {'level': 1},
#   'IC8': {'level': 1},
#   'C200': {'level': 1}},
#  'rewards': {'daveStatue': {'id': 'daveStatue'},
#   'extraTiles': {'id': 'extraTiles'},
#   'goldenDAVE': {'id': 'goldenDAVE'},
#   'improvedHCC': {'id': 'improvedHCC'},
#   'unblockVorg': {'id': 'unblockVorg'},
#   'KorathReward': {'id': 'KorathReward', 'value': 3},
#   'krallenReward': {'id': 'krallenReward', 'value': 5},
#   'unlockRezghul': {'id': 'unlockRezghul'},
#   'krallenBuffReward': {'id': 'krallenBuffReward', 'value': 5},
#   'spurtzCannonReward3': {'id': 'spurtzCannonReward3'},
#   'unblockSlimeattikus': {'id': 'unblockSlimeattikus'},
#   'yardPlannerExtraSlots': {'id': 'yardPlannerExtraSlots'}},
#  'aiattacks': {'lastAttack': 1738707194,
#   'lastattack': 0,
#   'nextAttack': 1767244715.624,
#   'attackPreference': 0,
#   'sessionsSinceLastAttack': 28},
#  'monsters': {'h': [['C12', 2460, []], ['C12', 2461, []]],
#   'hcc': [['C12', 10]],
#   'hid': [154, 159],
#   'saved': 1767244658,
#   'space': 540,
#   'hcount': 2,
#   'housed': {},
#   'hstage': [1, 1],
#   'finishtime': 1767416323,
#   'overdrivetime': 0,
#   'overdrivepower': 0},
#  'resources': {'r1': 8688242816,
#   'r2': 8656785536,
#   'r3': 9256785536,
#   'r4': 8743785536,
#   'r1max': 446310000,
#   'r2max': 446310000,
#   'r3max': 446310000,
#   'r4max': 446310000},
#  'iresources': {},
#  'lockerdata': {'C1': {'t': 2},
#   'C12': {'t': 2},
#   'C14': {'t': 2},
#   'C15': {'t': 2},
#   'C16': {'t': 2},
#   'C19': {'t': 2}},
#  'events': {'debugDate': 1767189726237,
#   'Brukkarg War': {'quotas': [None, None, None, None, None],
#    'reward': None,
#    'startDate': 0,
#    '_numAttempts': 0,
#    '_wavesDestroyed': 0,
#    '_yardsDestroyed': 0},
#   'Hell Raisers': {'startDate': 0},
#   'Creature Carnage': {'reward': None, 'startDate': 0},
#   'Monster Blitzkrieg': {'reward': None,
#    'startDate': 0,
#    '_numAttempts': 0,
#    '_wavesDestroyed': 0}},
#  'inventory': {},
#  'monsterbaiter': {'musk': 900, 'queue': {}, 'attackDir': 2},
#  'loot': {},
#  'attackreport': '"<ul><li><font color=\\"#999999\\">09s</font>: <font color=\\"#0000FF\\">23 Octo-ooze were flung in</font></li><li><font color=\\"#999999\\">12s</font>: <font color=\\"#0000FF\\">1 Level 5 Krallen was flung in</font></li><li><font color=\\"#999999\\">13s</font>: <font color=\\"#FF0000\\"><b>A Booby Trap exploded!</b> Damaging 10 monsters.</font></li><li><font color=\\"#999999\\">15s</font>: <font color=\\"#0000FF\\">1 Teratorn was flung in</font></li><li><font color=\\"#999999\\">18s</font>: <font color=\\"#FF0000\\"><b>A Booby Trap exploded!</b> Damaging 1 monsters.</font></li><li><font color=\\"#999999\\">21s</font>: <font color=\\"#0000FF\\">1 Teratorn was flung in</font></li><li><font color=\\"#999999\\">25s</font>: <font color=\\"#0000FF\\">9 Octo-ooze were flung in</font></li><li><font color=\\"#999999\\">29s</font>: <font color=\\"#0000FF\\">2 Teratorn were flung in</font></li><li><font color=\\"#999999\\">30s</font>: <font color=\\"#FF0000\\">A level 2 <b>Tesla Tower</b> was knocked down.</font></li><li><font color=\\"#999999\\">33s</font>: <font color=\\"#0000FF\\">6 Octo-ooze were flung in</font></li><li><font color=\\"#999999\\">38s</font>: <font color=\\"#FF0000\\">A level 2 <b>Laser Tower</b> was knocked down.</font></li><li><font color=\\"#999999\\">40s</font>: <font color=\\"#0000FF\\">4 Octo-ooze were flung in</font></li><li><font color=\\"#999999\\">44s</font>: <font color=\\"#0000FF\\">1 Level 2 Drull was flung in</font></li><li><font color=\\"#999999\\">50s</font>: <font color=\\"#FF0000\\">A level 2 <b>Laser Tower</b> was knocked down.</font></li><li><font color=\\"#999999\\">59s</font>: <font color=\\"#FF0000\\">A level 5 <b>Goo Factory</b> was knocked down.</font></li><li><font color=\\"#999999\\">01m 03s</font>: <font color=\\"#FF0000\\"><b>A Booby Trap exploded!</b> Damaging 4 monsters.</font></li><li><font color=\\"#999999\\">01m 03s</font>: <font color=\\"#0000FF\\">5 Octo-ooze were flung in</font></li><li><font color=\\"#999999\\">01m 09s</font>: <font color=\\"#FF0000\\">A level 9 <b>Storage Silo</b> was knocked down.</font></li><li><font color=\\"#999999\\">01m 10s</font>: <font color=\\"#FF0000\\">A level 2 <b>Tesla Tower</b> was knocked down.</font></li><li><font color=\\"#999999\\">01m 15s</font>: <font color=\\"#FF0000\\">A level 9 <b>Putty Squisher</b> was knocked down.</font></li><li><font color=\\"#999999\\">01m 21s</font>: <font color=\\"#0000FF\\">10 Octo-ooze were flung in</font></li><li><font color=\\"#999999\\">01m 22s</font>: <font color=\\"#FF0000\\">A level 5 <b>Pebble Shiner</b> was knocked down.</font></li><li><font color=\\"#999999\\">01m 27s</font>: <font color=\\"#FF0000\\">A level 9 <b>Goo Factory</b> was knocked down.</font></li><li><font color=\\"#999999\\">01m 30s</font>: <font color=\\"#A800FF\\">100,000 #r_putty# were catapulted in</font></li><li><font color=\\"#999999\\">01m 31s</font>: <font color=\\"#FF0000\\">A level 5 <b>Twig Snapper</b> was knocked down.</font></li><li><font color=\\"#999999\\">01m 33s</font>: <font color=\\"#FF0000\\">A level 5 <b>Putty Squisher</b> was knocked down.</font></li><li><font color=\\"#999999\\">01m 37s</font>: <font color=\\"#FF0000\\">A level 1 <b>Hatchery</b> was knocked down.</font></li><li><font color=\\"#999999\\">01m 41s</font>: <font color=\\"#FF0000\\">A level 9 <b>Storage Silo</b> was knocked down.</font></li><li><font color=\\"#999999\\">01m 51s</font>: <font color=\\"#FF0000\\">A level 1 <b>Housing</b> was knocked down.</font></li><li><font color=\\"#999999\\">01m 58s</font>: <font color=\\"#FF0000\\">A level 5 <b>Town Hall</b> was knocked down.</font></li><li><font color=\\"#999999\\">02m 02s</font>: <font color=\\"#FF0000\\">A level 1 <b>General Store</b> was knocked down.</font></li><li><font color=\\"#999999\\">02m 03s</font>: <font color=\\"#FF0000\\">A level 5 <b>Goo Factory</b> was knocked down.</font></li><li><font color=\\"#999999\\">02m 10s</font>: <font color=\\"#FF0000\\">A level 1 <b>Housing</b> ...
#  'storedata': {},
#  'coords': {},
#  'quests': {'C3': 1,
#   'C4': 1,
#   'C5': 1,
#   'C6': 1,
#   'C7': 1,
#   'C9': 1,
#   'D1': 2,
#   'M1': 1,
#   'S1': 1,
#   'S2': 1,
#   'S3': 1,
#   'S4': 1,
#   'T1': 2,
#   'T2': 1,
#   'T3': 1,
#   'U1': 1,
#   'BK1': 1,
#   'C10': 1,
#   'C11': 1,
#   'C12': 1,
#   'C13': 1,
#   'C14': 1,
#   'C15': 1,
#   'C16': 1,
#   'C17': 2,
#   'C18': 2,
#   'C51': 1,
#   'CR1': 1,
#   'CR2': 1,
#   'CR3': 2,
#   'HG2': 1,
#   'HG3': 1,
#   'UG3': 1,
#   'UC12': 1,
#   'INVITE1': 2,
#   'INVITE5': 1,
#   'INVITE10': 1},
#  'player': {},
#  'krallen': {},
#  'siege': None,
#  'buildingresources': {'t': 1767245388,
#   'b20444959346263': {'r1': 0, 'r2': 0, 'r3': 0, 'r4': 0},
#   'b20444959347264': {'r1': 0, 'r2': 0, 'r3': 0, 'r4': 0},
#   'b20444959348262': {'r1': 144, 'r2': 144, 'r3': 144, 'r4': 144},
#   'b20444959348263': {'r1': 156, 'r2': 156, 'r3': 156, 'r4': 156},
#   'b20444959350261': {'r1': 128, 'r2': 136, 'r3': 128, 'r4': 128},
#   'b20444959350263': {'r1': 152, 'r2': 152, 'r3': 152, 'r4': 152},
#   'b20444959351264': {'r1': 0, 'r2': 0, 'r3': 0, 'r4': 0},
#   'b20444959358270': {'r1': 148, 'r2': 148, 'r3': 148, 'r4': 148},
#   'b20444959358273': {'r1': 136, 'r2': 136, 'r3': 136, 'r4': 136},
#   'b20444959359269': {'r1': 144, 'r2': 144, 'r3': 144, 'r4': 144},
#   'b20444959359273': {'r1': 120, 'r2': 120, 'r3': 120, 'r4': 120},
#   'b20444959360262': {'r1': 152, 'r2': 152, 'r3': 152, 'r4': 152},
#   'b20444959360270': {'r1': 128, 'r2': 128, 'r3': 128, 'r4': 128},
#   'b20444959360271': {'r1': 120, 'r2': 120, 'r3': 120, 'r4': 120},
#   'b20444959360273': {'r1': 112, 'r2': 112, 'r3': 112, 'r4': 112},
#   'b20444959360274': {'r1': 108, 'r2': 108, 'r3': 108, 'r4': 108},
#   'b20444959360276': {'r1': 0, 'r2': 0, 'r3': 0, 'r4': 0},
#   'b20444959361265': {'r1': 128, 'r2': 128, 'r3': 128, 'r4': 128},
#   'b20444959362271': {'r1': 136, 'r2': 128, 'r3': 128, 'r4': 128},
#   'b20444959364280': {'r1': 148, 'r2': 148, 'r3': 148, 'r4': 148},
#   'b20444959365282': {'r1': 128, 'r2': 128, 'r3': 128, 'r4': 128},
#   'b20444959365283': {'r1': 116, 'r2': 116, 'r3': 116, 'r4': 116},
#   'b20444959366282': {'r1': 148, 'r2': 148, 'r3': 148, 'r4': 148},
#   'b20444959369279': {'r1': 164, 'r2': 164, 'r3': 164, 'r4': 164}},
#  'mushrooms': {'l': [], 's': 0},
#  'frontpage': {'Replayable Events': {'name': 'Replayable Events'}},
#  'attackloot': {},
#  'lootreport': {},
#  'attackersiege': None,
#  'monsterupdate': [],
#  'savetemplate': [],
#  'updates': [],
#  'effects': [],
#  'homebase': ['358', '272'],
#  'outposts': [[359, 273, '20444959359273'],
#   [358, 273, '20444959358273'],
#   [359, 269, '20444959359269'],
#   [361, 265, '20444959361265'],
#   [360, 262, '20444959360262'],
#   [358, 270, '20444959358270'],
#   [360, 270, '20444959360270'],
#   [360, 271, '20444959360271'],
#   [360, 273, '20444959360273'],
#   [362, 271, '20444959362271'],
#   [364, 280, '20444959364280'],
#   [365, 282, '20444959365282'],
#   [365, 283, '20444959365283'],
#   [366, 282, '20444959366282'],
#   [369, 279, '20444959369279'],
#   [370, 276, '20444959370276'],
#   [370, 278, '20444959370278'],
#   [371, 276, '20444959371276'],
#   [373, 275, '20444959373275'],
#   [358, 274, '20444959358274'],
#   [358, 275, '20444959358275'],
#   [358, 276, '20444959358276'],
#   [358, 277, '20444959358277'],
#   [358, 278, '20444959358278'],
#   [359, 272, '20444959359272'],
#   [359, 274, '20444959359274'],
#   [359, 275, '20444959359275'],
#   [359, 276, '20444959359276'],
#   [359, 277, '20444959359277'],
#   [359, 278, '20444959359278'],
#   [359, 279, '20444959359279'],
#   [359, 280, '20444959359280'],
#   [360, 272, '20444959360272'],
#   [360, 274, '20444959360274'],
#   [360, 275, '20444959360275'],
#   [360, 276, '20444959360276'],
#   [360, 277, '20444959360277'],
#   [360, 278, '20444959360278'],
#   [360, 279, '20444959360279'],
#   [360, 280, '20444959360280'],
#   [360, 281, '20444959360281'],
#   [360, 282, '20444959360282'],
#   [361, 272, '20444959361272'],
#   [361, 273, '20444959361273'],
#   [361, 274, '20444959361274'],
#   [361, 275, '20444959361275'],
#   [361, 276, '20444959361276'],
#   [361, 277, '20444959361277'],
#   [361, 278, '20444959361278'],
#   [361, 279, '20444959361279'],
#   [361, 280, '20444959361280'],
#   [361, 281, '20444959361281'],
#   [361, 282, '20444959361282'],
#   [362, 272, '20444959362272'],
#   [362, 273, '20444959362273'],
#   [362, 274, '20444959362274'],
#   [362, 275, '20444959362275'],
#   [362, 276, '20444959362276'],
#   [362, 277, '20444959362277'],
#   [362, 278, '20444959362278'],
#   [362, 279, '20444959362279'],
#   [362, 280, '20444959362280'],
#   [362, 281, '20444959362281'],
#   [362, 282, '20444959362282'],
#   [363, 272, '20444959363272'],
#   [363, 273, '20444959363273'],
#   [363, 274, '20444959363274'],
#   [363, 275, '20444959363275'],
#   [363, 276, '20444959363276'],
#   [363, 277, '20444959363277'],
#   [363, 278, '20444959363278'],
#   [363, 279, '20444959363279'],
#   [363, 280, '20444959363280'],
#   [363, 281, '20444959363281'],
#   [363, 282, '20444959363282'],
#   [364, 272, '20444959364272'],
#   [364, 273, '20444959364273'],
#   [364, 274, '20444959364274'],
#   [364, 275, '20444959364275'],
#   [364, 276, '20444959364276'],
#   [364, 279, '20444959364279'],
#   [364, 281, '20444959364281'],
#   [364, 282, '20444959364282'],
#   [365, 272, '20444959365272'],
#   [365, 273, '20444959365273'],
#   [365, 274, '20444959365274'],
#   [365, 275, '20444959365275'],
#   [365, 276, '20444959365276'],
#   [365, 281, '20444959365281'],
#   [366, 272, '20444959366272'],
#   [356, 268, '20444959356268'],
#   [357, 267, '20444959357267'],
#   [360, 264, '20444959360264'],
#   [360, 268, '20444959360268'],
#   [361, 263, '20444959361263'],
#   [361, 267, '20444959361267'],
#   [362, 266, '20444959362266'],
#   [363, 265, '20444959363265'],
#   [364, 263, '20444959364263'],
#   [353, 268, '20444959353268'],
#   [353, 271, '20444959353271'],
#   [354, 270, '20444959354270'],
#   [355, 269, '20444959355269'],
#   [357, 271, '20444959357271'],
#   [357, 274, '20444959357274'],
#   [351, 266, '20444959351266'],
#   [351, 272, '20444959351272'],
#   [352, 272, '20444959352272'],
#   [351, 262, '20444959351262'],
#   [350, 261, '20444959350261'],
#   [366, 273, '20444959366273'],
#   [371, 273, '20444959371273'],
#   [373, 273, '20444959373273'],
#   [374, 273, '20444959374273'],
#   [371, 274, '20444959371274'],
#   [371, 275, '20444959371275'],
#   [371, 277, '20444959371277'],
#   [371, 278, '20444959371278'],
#   [371, 279, '20444959371279'],
#   [371, 280, '20444959371280'],
#   [371, 281, '20444959371281'],
#   [371, 282, '20444959371282'],
#   [371, 283, '20444959371283'],
#   [350, 262, '20444959350262'],
#   [350, 263, '20444959350263'],
#   [350, 264, '20444959350264'],
#   [350, 265, '20444959350265'],
#   [350, 266, '20444959350266'],
#   [350, 267, '20444959350267'],
#   [350, 268, '20444959350268'],
#   [350, 269, '20444959350269'],
#   [350, 271, '20444959350271'],
#   [351, 261, '20444959351261'],
#   [351, 263, '20444959351263'],
#   [351, 264, '20444959351264'],
#   [351, 265, '20444959351265'],
#   [351, 267, '20444959351267'],
#   [351, 268, '20444959351268'],
#   [351, 269, '20444959351269'],
#   [351, 270, '20444959351270'],
#   [351, 271, '20444959351271'],
#   [352, 261, '20444959352261'],
#   [346, 262, '20444959346262'],
#   [346, 263, '20444959346263'],
#   [346, 264, '20444959346264'],
#   [346, 265, '20444959346265'],
#   [347, 262, '20444959347262'],
#   [347, 263, '20444959347263'],
#   [347, 264, '20444959347264'],
#   [347, 271, '20444959347271'],
#   [347, 272, '20444959347272'],
#   [348, 262, '20444959348262'],
#   [348, 263, '20444959348263'],
#   [348, 264, '20444959348264'],
#   [348, 271, '20444959348271'],
#   [348, 272, '20444959348272'],
#   [349, 262, '20444959349262'],
#   [349, 263, '20444959349263'],
#   [349, 264, '20444959349264'],
#   [349, 270, '20444959349270'],
#   [349, 271, '20444959349271'],
#   [349, 272, '20444959349272'],
#   [350, 272, '20444959350272'],
#   [352, 262, '20444959352262'],
#   [352, 263, '20444959352263'],
#   [352, 264, '20444959352264'],
#   [352, 265, '20444959352265'],
#   [352, 266, '20444959352266'],
#   [352, 267, '20444959352267'],
#   [352, 268, '20444959352268'],
#   [352, 269, '20444959352269'],
#   [352, 270, '20444959352270'],
#   [352, 271, '20444959352271'],
#   [353, 262, '20444959353262'],
#   [353, 263, '20444959353263'],
#   [353, 264, '20444959353264'],
#   [353, 265, '20444959353265'],
#   [353, 266, '20444959353266'],
#   [353, 267, '20444959353267'],
#   [353, 269, '20444959353269'],
#   [353, 270, '20444959353270'],
#   [354, 262, '20444959354262'],
#   [354, 263, '20444959354263'],
#   [354, 264, '20444959354264'],
#   [354, 265, '20444959354265'],
#   [354, 266, '20444959354266'],
#   [354, 267, '20444959354267'],
#   [354, 268, '20444959354268'],
#   [354, 269, '20444959354269'],
#   [354, 271, '20444959354271'],
#   [355, 262, '20444959355262'],
#   [355, 263, '20444959355263'],
#   [355, 264, '20444959355264'],
#   [355, 265, '20444959355265'],
#   [355, 266, '20444959355266'],
#   [360, 258, '20444959360258'],
#   [360, 259, '20444959360259'],
#   [360, 260, '20444959360260'],
#   [360, 261, '20444959360261'],
#   [360, 263, '20444959360263'],
#   [360, 265, '20444959360265'],
#   [360, 266, '20444959360266'],
#   [360, 267, '20444959360267'],
#   [361, 258, '20444959361258'],
#   [361, 259, '20444959361259'],
#   [361, 260, '20444959361260'],
#   [361, 261, '20444959361261'],
#   [361, 262, '20444959361262'],
#   [361, 264, '20444959361264'],
#   [361, 266, '20444959361266'],
#   [361, 268, '20444959361268'],
#   [362, 258, '20444959362258'],
#   [362, 259, '20444959362259'],
#   [362, 260, '20444959362260'],
#   [362, 261, '20444959362261'],
#   [362, 262, '20444959362262'],
#   [362, 263, '20444959362263'],
#   [362, 264, '20444959362264'],
#   [362, 265, '20444959362265'],
#   [362, 267, '20444959362267'],
#   [362, 268, '20444959362268'],
#   [363, 258, '20444959363258'],
#   [363, 259, '20444959363259']],
#  'wmstatus': [],
#  'chatservers': ['bym-chat.kixeye.com'],
#  'achieved': [17, 1, 2, 3, 6, 15, 22],
#  'gifts': [],
#  'sentinvites': [],
#  'sentgifts': [],
#  'fbpromos': [],
#  'powerups': [],
#  'attpowerups': []}

# %%
# Conquer all bases within range, expanding from your main base
result = client.destroy_all_enemy_bases(
    x=360, y=258, current_username='josesteve', width=50, height=50, include_wild_monsters=True
)

# %%
client.increment_resources(r1=50_000_000, r2=50_000_000, r3=50_000_000, r4=50_000_000)
# Out:
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
client.set_resources(r1=50_000_000_000, r2=50_000_000_000, r3=50_000_000_000, r4=50_000_000_000)
# Out:
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
client.set_champion(
    [
        {"pl": 2, "t": 5, "l": 5, "hp": 50000000, "ft": 0, "status": 0},
        {"pl": 1, "t": 3, "l": 6, "hp": 50000000, "ft": 3, "status": 0},
        {
            "status": 0,
            "log": "undefined",
            "fd": 0,
            "l": 6,
            "fb": 0,
            "hp": 20000,
            "t": 2,
            "pl": 1,
            "ft": 1767329417,
        },
        {
            "status": 0,
            "log": "undefined",
            "fd": 0,
            "l": 6,
            "fb": 0,
            "hp": 80000,
            "t": 1,
            "pl": 1,
            "ft": 1767329531,
        },
        {
      "status": 0,
      "log": "undefined",
      "fd": 0,
      "l": 6,
      "fb": 0,
      "hp": 96000,
      "t": 4,
      "pl": 3,
      "ft": 1767329614
    }
    ]
)
# Out:
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
client.purchase_item("MUSHROOM2", 1)
# Out:
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
client.set_auto_sync(True)
for i in range(10000):
    client.purchase_item("MUSHROOM2", 1)
# Out:
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
client.purchase_item("MUSHROOM2", 1)
# Out:
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
client.base_data.resources
# Out:
# Resources(r1=1498763, r2=1487366, r3=150681800, r4=424720000, r1max=10310000, r2max=10310000, r3max=10310000, r4max=10310000)

# %%
client.set_resources(r1=500_000_000, r2=500_000_000, r3=500_000_000, r4=500_000_000)
# Out:
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# {'error': 0,
#  'basesaveid': 1472264,
#  'baseid': '14926',
#  'homebaseid': '14926',
#  'userid': 1008523,
#  'saveuserid': 1008523,
#  'attackid': 0,
#  'id': 1767205490,
#  'baseid_inferno': 0,
#  'wmid': 0,
#  'type': 'main',
#  'createtime': 1767182637,
#  'savetime': 1767205498,
#  'seed': 0,
#  'bookmarked': 0,
#  'fan': 0,
#  'emailshared': 0,
#  'unreadmessages': 0,
#  'giftsentcount': 0,
#  'canattack': False,
#  'fortifycellid': 0,
#  'name': 'josesteve',
#  'level': 1,
#  'catapult': 1,
#  'flinger': 3,
#  'destroyed': 0,
#  'damage': 0,
#  'locked': 0,
#  'points': '1870564',
#  'basevalue': '2080684',
#  'tutorialstage': 205,
#  'protected': 0,
#  'lastupdate': 0,
#  'usemap': 1,
#  'credits': 21,
#  'champion': 'null',
#  'empiredestroyed': 0,
#  'worldid': '2132bac8-cfc3-462d-b9b0-33171c0fc650',
#  'event_score': 0,
#  'chatenabled': 0,
#  'relationship': 0,
#  'timeplayed': 0,
#  'version': 128,
#  'clienttime': 0,
#  'baseseed': 0,
#  'healtime': 0,
#  'empirevalue': 2080684,
#  'basename': 'basename',
#  'over': 0,
#  'protect': 0,
#  'purchasecomplete': 0,
#  'attacks': [],
#  'buildingkeydata': {},
#  'buildinghealthdata': {},
#  'buildingdata': {'0': {'id': 0, 't': 14, 'X': -70, 'Y': 0, 'l': 6},
#   '1': {'id': 1,
#    't': 1,
#    'X': 60,
#    'Y': 0,
#    'l': 3,
#    'st': 0,
#    'cP': 7,
#    'rCP': 7,
#    'pr': 1},
#   '2': {'id': 2,
#    't': 2,
#    'X': 60,
#    'Y': 70,
#    'l': 2,
#    'st': 0,
#    'cP': 7,
#    'rCP': 7,
#    'pr': 1},
#   '3': {'id': 3, 't': 12, 'X': 60, 'Y': -70},
#   '25': {'id': 25, 't': 21, 'X': -10, 'Y': -70},
#   '26': {'id': 26, 't': 15, 'X': -170, 'Y': -170, 'l': 4},
#   '27': {'id': 27, 't': 5, 'X': -160, 'Y': 40, 'l': 3},
#   '28': {'id': 28, 't': 11, 'X': -265, 'Y': -35},
#   '49': {'id': 49,
#    't': 13,
#    'X': 0,
#    'Y': -180,
#    'rCP': 3115,
#    'rPS': 1,
#    'mq': [['C12', 14], ['C12', 2]],
#    'rIP': 'C12'},
#   '74': {'id': 74,
#    't': 4,
#    'X': 110,
#    'Y': -150,
#    'st': 696,
#    'cP': 4,
#    'rCP': 4,
#    'pr': 1},
#   '93': {'id': 93,
#    't': 1,
#    'X': -130,
#    'Y': 140,
#    'st': 0,
#    'cP': 4,
#    'rCP': 4,
#    'pr': 1},
#   '94': {'id': 94,
#    't': 1,
#    'X': -60,
#    'Y': 140,
#    'st': 0,
#    'cP': 5,
#    'rCP': 5,
#    'pr': 1},
#   '95': {'id': 95,
#    't': 1,
#    'X': 15,
#    'Y': 145,
#    'st': 0,
#    'cP': 7,
#    'rCP': 7,
#    'pr': 1},
#   '96': {'id': 96,
#    't': 1,
#    'X': 90,
#    'Y': 140,
#    'st': 2,
#    'cP': 10,
#    'rCP': 10,
#    'pr': 1},
#   '97': {'id': 97,
#    't': 1,
#    'X': -210,
#    'Y': 140,
#    'st': 0,
#    'cP': 1,
#    'rCP': 1,
#    'pr': 1},
#   '98': {'id': 98,
#    't': 2,
#    'X': -170,
#    'Y': 220,
#    'st': 0,
#    'cP': 4,
#    'rCP': 4,
#    'pr': 1},
#   '99': {'id': 99, 't': 15, 'X': -345, 'Y': -255, 'l': 5},
#   '100': {'id': 100, 't': 15, 'X': -150, 'Y': -360, 'l': 3},
#   '101': {'id': 101, 't': 8, 'X': -380, 'Y': -50, 'l': 4},
#   '102': {'id': 102,
#    't': 13,
#    'X': 25,
#    'Y': -285,
#    'rCP': 1706,
#    'rPS': 1,
#    'mq': [['C15', 11]],
#    'rIP': 'C15'},
#   '103': {'id': 103, 't': 51, 'X': -350, 'Y': 60},
#   '104': {'id': 104, 't': 13, 'X': 125, 'Y': -275},
#   '105': {'id': 105, 't': 13, 'X': 10, 'Y': -390},
#   '106': {'id': 106, 't': 13, 'X': 125, 'Y': -385},
#   '107': {'id': 107, 't': 114, 'X': 160, 'Y': -30},
#   '124': {'id': 124,
#    't': 3,
#    'X': -95,
#    'Y': 225,
#    'st': 56,
#    'cP': 7,
#    'rCP': 7,
#    'pr': 1},
#   '125': {'id': 125, 't': 6, 'X': -435, 'Y': -205, 'l': 4},
#   '126': {'id': 126, 't': 6, 'X': -435, 'Y': -295, 'l': 4},
#   '127': {'id': 127, 't': 6, 'X': -430, 'Y': -390, 'l': 4},
#   '128': {'id': 128, 't': 6, 'X': -345, 'Y': -355, 'l': 4},
#   '129': {'id': 129, 't': 6, 'X': -255, 'Y': -345, 'l': 4}},
#  'researchdata': {'b135': 1},
#  'stats': {'moga': 0,
#   'mg': 4,
#   'updateid_mr3': 0,
#   'mob': 0,
#   'updateid': 0,
#   'inferno': 0,
#   'updateid_mr2': 2,
#   'mobg': 0,
#   'mp': 7,
#   'popupdata': {'popupStates': {}, 'lastDialog': 0},
#   'achievements': {'c': {'1': 1, '2': 1, '6': 1},
#    's': {'stockpile': 0,
#     'upgrade_champ2': 0,
#     'wmoutpost': 0,
#     'alliance': 0,
#     'upgrade_champ1': 0,
#     'thlevel': 6,
#     'upgrade_champ3': 0,
#     'blocksbuilt': 0,
#     'hugerage': 0,
#     'DESCENT_LEVEL': 0,
#     'playeroutpost': 0,
#     'wm2hall': 0,
#     'unlock_monster': 0,
#     'UNDERHALL_LEVEL': 0,
#     'heavytraps': 0,
#     'map2': 1,
#     'monstersblended': 0,
#     'INFERNO_QUESTS_COMPLETED': 0,
#     'starterkit': 0}},
#   'other': {'pi': 1767192074,
#    'lastKOTHTier': 0,
#    'mrl': 2,
#    'lastKOTHScore': 0,
#    'infernoUpgradeShown': 1,
#    's': 1,
#    'lastTime': 1767195065,
#    'expiration': 0,
#    'wmi_wave': 0,
#    'mmscore': 0,
#    'lastLevel': 1,
#    'mutemusic': 1,
#    'lastWmi1EventEnd': 1765926000,
#    'renewal': 0,
#    'changedToMR2': 2}},
#  'academy': {'C14': {'level': 1},
#   'C200': {'level': 1},
#   'C15': {'level': 1},
#   'C3': {'level': 1},
#   'C16': {'level': 1},
#   'C4': {'level': 1},
#   'C19': {'level': 1},
#   'C5': {'level': 1},
#   'IC1': {'level': 1},
#   'C12': {'level': 1},
#   'IC2': {'level': 1},
#   'C7': {'level': 1},
#   'IC3': {'level': 1},
#   'C6': {'level': 1},
#   'C8': {'level': 1},
#   'C17': {'level': 1},
#   'C9': {'level': 1},
#   'IC5': {'level': 1},
#   'IC4': {'level': 1},
#   'C10': {'level': 1},
#   'IC6': {'level': 1},
#   'C11': {'level': 1},
#   'IC7': {'level': 1},
#   'C1': {'level': 1},
#   'C18': {'level': 1},
#   'IC8': {'level': 1},
#   'C2': {'level': 1},
#   'C13': {'level': 1}},
#  'rewards': {'unblockSlimeattikus': {'id': 'unblockSlimeattikus'},
#   'daveStatue': {'id': 'daveStatue'},
#   'goldenDAVE': {'id': 'goldenDAVE'},
#   'unblockVorg': {'id': 'unblockVorg'},
#   'yardPlannerExtraSlots': {'id': 'yardPlannerExtraSlots'},
#   'improvedHCC': {'id': 'improvedHCC'},
#   'extraTiles': {'id': 'extraTiles'}},
#  'aiattacks': {'nextAttack': 1767195376.415,
#   'sessionsSinceLastAttack': 9,
#   'lastattack': 0,
#   'attackPreference': 0},
#  'monsters': {'h': [['C15', 1706, [['C15', 11]]],
#    ['', 0, []],
#    ['', 0, []],
#    ['', 0, []],
#    ['C12', 3115, [['C12', 14], ['C12', 2]]]],
#   'hcc': [],
#   'overdrivetime': 0,
#   'space': 1150,
#   'saved': 1767195648,
#   'housed': {},
#   'hstage': [1, 0, 0, 0, 1],
#   'hid': [102, 104, 105, 106, 49],
#   'finishtime': 0,
#   'overdrivepower': 0,
#   'hcount': 5},
#  'resources': {'r1': 500000000,
#   'r2': 500000000,
#   'r3': 500000000,
#   'r4': 500000000,
#   'r1max': 310000,
#   'r2max': 310000,
#   'r3max': 310000,
#   'r4max': 310000},
#  'iresources': {'r1': 0,
#   'r2': 0,
#   'r3': 0,
#   'r4': 0,
#   'r1max': 10000,
#   'r2max': 10000,
#   'r3max': 10000,
#   'r4max': 10000},
#  'lockerdata': {'C15': {'t': 2},
#   'C12': {'t': 2},
#   'C14': {'t': 1},
#   'C1': {'t': 2}},
#  'events': {'Brukkarg War': {'_yardsDestroyed': 0,
#    'reward': None,
#    'startDate': 0,
#    '_wavesDestroyed': 0,
#    '_numAttempts': 0,
#    'quotas': [None, None, None, None, None]},
#   'Monster Blitzkrieg': {'startDate': 0,
#    '_wavesDestroyed': 0,
#    'reward': None,
#    '_numAttempts': 0},
#   'Creature Carnage': {'startDate': 0, 'reward': None},
#   'debugDate': 1767189726237,
#   'Hell Raisers': {'startDate': 0}},
#  'inventory': {},
#  'monsterbaiter': {'musk': 600, 'queue': {}, 'attackDir': 1},
#  'loot': {},
#  'storedata': {'FQ': {'q': 708},
#   'BEW': {'q': 4},
#   'BST': {'e': 1767787840, 'q': 1},
#   'ENL': {'q': 6},
#   'IEV': {'q': 684},
#   'IHE': {'q': 28},
#   'IUN': {'q': 1444},
#   'SP4': {'q': 3498},
#   'BRTOPUP': {'q': 6},
#   'QINVITE1': {'q': 1},
#   'MUSHROOM1': {'q': 1045},
#   'MUSHROOM2': {'q': 6331}},
#  'coords': {},
#  'quests': {'C14': 1,
#   'C15': 1,
#   'C16': 1,
#   'S2': 1,
#   'C51': 1,
#   'INVITE5': 1,
#   'S1': 1,
#   'U1': 1,
#   'S4': 1,
#   'D1': 2,
#   'T1': 2,
#   'M1': 1,
#   'CR3': 2,
#   'CR1': 1,
#   'C17': 2,
#   'INVITE10': 1,
#   'C9': 1,
#   'C18': 2,
#   'BK1': 1,
#   'INVITE1': 2,
#   'S3': 1,
#   'UC12': 1,
#   'HG2': 1,
#   'C13': 1,
#   'CR2': 1},
#  'player': {},
#  'krallen': {'loot': 750000000000, 'tier': 5, 'wins': 5, 'countdown': 443189},
#  'buildingresources': {'t': 1767195648},
#  'mushrooms': {'s': 1767183664,
#   'l': [[4, 120, -480],
#    [1, 0, -460],
#    [1, -30, -460],
#    [1, -420, 310],
#    [2, -580, 150],
#    [2, -620, 330],
#    [5, -442, 361],
#    [5, -240, 560],
#    [4, 701, 310],
#    [3, 620, 380],
#    [1, 620, 460],
#    [2, 540, 480],
#    [1, 740, 550]]},
#  'frontpage': {'Replayable Events': {'name': 'Replayable Events'}},
#  'attackloot': {},
#  'lootreport': {},
#  'attackersiege': {},
#  'monsterupdate': [],
#  'savetemplate': [],
#  'updates': [],
#  'effects': [[315, 80, 's5', 5495],
#   [314, 105, 's1', 5495],
#   [249, 71, 's2', 5495],
#   [305, 64, 's5', 5495],
#   [281, 16, 's4', 5495],
#   [237, 31, 's2', 5495],
#   [219, 20, 's2', 5495],
#   [207, 58, 's4', 5495],
#   [209, 78, 's3', 5495],
#   [105, 3, 's3', 5495],
#   [155, -9, 's2', 5495],
#   [153, -9, 's3', 5495],
#   [140, -19, 's3', 5495],
#   [125, -18, 's2', 5495],
#   [72, 32, 's2', 5495],
#   [118, -10, 's5', 5495],
#   [108, -4, 's2', 5495],
#   [92, 0, 's2', 5495],
#   [109, -28, 's5', 5495],
#   [80, -4, 's1', 5495],
#   [84, 5, 's4', 5495],
#   [89, 0, 's3', 5495],
#   [44, 6, 's4', 5495],
#   [9, -48, 's2', 5495],
#   [51, -15, 's3', 5495],
#   [107, -3, 's3', 5495],
#   [26, -4, 's5', 5495],
#   [10, 9, 's4', 5495],
#   [153, -34, 's5', 5495],
#   [66, 13, 's2', 5495],
#   [155, 0, 's3', 5495],
#   [143, 0, 's3', 5495],
#   [159, 30, 's1', 5495],
#   [92, 18, 's1', 5495],
#   [245, 17, 's2', 5495],
#   [347, 44, 's2', 5495],
#   [352, 53, 's5', 5495],
#   [393, 59, 's5', 5495],
#   [285, 46, 's4', 5495],
#   [373, 26, 's1', 5495],
#   [-253, 5, 's5', 165],
#   [-250, -5, 's3', 165],
#   [-274, -16, 's3', 165],
#   [-177, 16, 's2', 165],
#   [-146, -43, 's5', 165],
#   [-319, 32, 's1', 165],
#   [-296, 74, 's1', 165],
#   [-391, 55, 's2', 165],
#   [-288, 13, 's2', 165],
#   [-329, 30, 's5', 165],
#   [-183, -146, 's1', 165],
#   [-188, -141, 's1', 165],
#   [-163, -157, 's5', 165],
#   [-235, -153, 's4', 165],
#   [-253, -133, 's4', 165],
#   [-294, -202, 's2', 165],
#   [-294, -198, 's3', 165],
#   [-264, -225, 's1', 165],
#   [-359, -232, 's5', 165],
#   [-391, -204, 's3', 165],
#   [-307, -217, 's5', 165],
#   [-311, -201, 's5', 165],
#   [-261, -204, 's5', 165],
#   [-351, -185, 's5', 165],
#   [-223, -151, 's3', 165],
#   [-310, -214, 's2', 165],
#   [-308, -220, 's2', 165],
#   [-311, -196, 's1', 165],
#   [-345, -229, 's2', 165],
#   [-301, -160, 's4', 165],
#   [-305, -237, 's3', 165],
#   [-325, -236, 's2', 165],
#   [-324, -189, 's3', 165],
#   [-378, -193, 's3', 165],
#   [-363, -214, 's4', 165],
#   [-1, -1, 's2', 165],
#   [0, -13, 's2', 165],
#   [-17, -63, 's3', 165],
#   [24, -21, 's1', 165],
#   [-25, 1, 's3', 165]],
#  'homebase': ['358', '272'],
#  'outposts': [[359, 273, '20444959359273'], [358, 273, '20444959358273']],
#  'wmstatus': [],
#  'chatservers': ['bym-chat.kixeye.com'],
#  'achieved': [],
#  'gifts': [],
#  'sentinvites': [],
#  'sentgifts': [],
#  'fbpromos': [],
#  'powerups': [],
#  'attpowerups': [],
#  'fbid': None,
#  'cantmovetill': None,
#  'attackreport': None,
#  'siege': None}

# %%
client.base_data.credits
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 client.base_data.credits
#
# AttributeError: 'BaseData' object has no attribute 'credits'

# %%
for i in range(50000):
    client.add_credits("MUSHROOM1", 1)
# Out:
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ...
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'server.bymrefitted.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 for i in range(50000):
# ----> 2     client.add_credits("MUSHROOM1", 1)
#
# File ~/Documents/learn/bymr-api/examples/../bymr_api/client.py:890, in BYMRClient.add_credits(self, item_id, quantity)
#     873 def add_credits(self, item_id: str, quantity: int = 1) -> Dict[str, Any]:
#     874     """
#     875     Add credits by purchasing an item (alias for purchase_item with auto_save=True).
#     876
#    (...)    888         ```
#     889     """
# --> 890     return self.purchase_item(item_id, quantity, auto_save=True)
#
# File ~/Documents/learn/bymr-api/examples/../bymr_api/client.py:857, in BYMRClient.purchase_item(self, item_id, quantity, auto_save)
#     845 # Override resources with zero-delta to prevent unintended increments
#     846 request_data["resources"] = {
#     847     "r1": 0,
#     848     "r2": 0,
#    (...)    854     "r4max": self.base_data.resources.r4max,
#     855 }
# --> 857 response = self._make_request(
#     858     method="POST",
#     859     endpoint="/base/save",
#     860     data=request_data,
#     861 )
#     863 # Update local state with response
#     864 base_data_dict = self._extract_base_data_from_response(response)
#
# File ~/Documents/learn/bymr-api/examples/../bymr_api/client.py:225, in BYMRClient._make_request(self, method, endpoint, data, params)
#     222             form_data[key] = str(value)
#     223     encoded_data = urlencode(form_data)
# --> 225 response = self.session.request(
#     226     method=method,
#     227     url=url,
#     228     data=encoded_data,
#     229     params=params,
#     230     timeout=self.timeout,
#     231     verify=self.verify_ssl,
#     232     headers=(
#     233         {"Content-Type": "application/x-www-form-urlencoded"}
#     234         if encoded_data
#     235         else None
#     236     ),
#     237 )
#     239 # Handle different status codes
#     240 if response.status_code == 401:
#
# File ~/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/requests/adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File ~/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connection.py:571, in HTTPConnection.getresponse(self)
#     568 _shutdown = getattr(self.sock, "shutdown", None)
#     570 # Get the response from http.client.HTTPConnection
# --> 571 httplib_response = super().getresponse()
#     573 try:
#     574     assert_header_parsing(httplib_response.msg)
#
# File /opt/homebrew/Cellar/python@3.14/3.14.2/Frameworks/Python.framework/Versions/3.14/lib/python3.14/http/client.py:1450, in HTTPConnection.getresponse(self)
#    1448 try:
#    1449     try:
# -> 1450         response.begin()
#    1451     except ConnectionError:
#    1452         self.close()
#
# File /opt/homebrew/Cellar/python@3.14/3.14.2/Frameworks/Python.framework/Versions/3.14/lib/python3.14/http/client.py:336, in HTTPResponse.begin(self)
#     334 # read until we get a non-100 response
#     335 while True:
# --> 336     version, status, reason = self._read_status()
#     337     if status != CONTINUE:
#     338         break
#
# File /opt/homebrew/Cellar/python@3.14/3.14.2/Frameworks/Python.framework/Versions/3.14/lib/python3.14/http/client.py:297, in HTTPResponse._read_status(self)
#     296 def _read_status(self):
# --> 297     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     298     if len(line) > _MAXLINE:
#     299         raise LineTooLong("status line")
#
# File /opt/homebrew/Cellar/python@3.14/3.14.2/Frameworks/Python.framework/Versions/3.14/lib/python3.14/socket.py:725, in SocketIO.readinto(self, b)
#     723     raise OSError("cannot read from timed out object")
#     724 try:
# --> 725     return self._sock.recv_into(b)
#     726 except timeout:
#     727     self._timeout_occurred = True
#
# File /opt/homebrew/Cellar/python@3.14/3.14.2/Frameworks/Python.framework/Versions/3.14/lib/python3.14/ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/homebrew/Cellar/python@3.14/3.14.2/Frameworks/Python.framework/Versions/3.14/lib/python3.14/ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
for i in range(1000):
    client.add_credits("MUSHROOM1", 1)
# Out:
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /Users/yihein.chai/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '127.0.0.1'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 2
#       1 for i in range(1000):
# ----> 2     client.add_credits("MUSHROOM1", 1)
#
# File ~/Documents/learn/bymr-api/examples/../bymr_api/client.py:794, in BYMRClient.add_credits(self, item_id, quantity)
#     777 def add_credits(self, item_id: str, quantity: int = 1) -> Dict[str, Any]:
#     778     """
#     779     Add credits by purchasing an item (alias for purchase_item with auto_save=True).
#     780
#    (...)    792         ```
#     793     """
# --> 794     return self.purchase_item(item_id, quantity, auto_save=True)
#
# File ~/Documents/learn/bymr-api/examples/../bymr_api/client.py:763, in BYMRClient.purchase_item(self, item_id, quantity, auto_save)
#     760 request_data = self.base_data.to_dict()
#     761 request_data["purchase"] = [item_id, quantity]
# --> 763 response = self._make_request(
#     764     method="POST",
#     765     endpoint="/base/save",
#     766     data=request_data,
#     767 )
#     769 # Update local state
#     770 self._last_response = response
#
# File ~/Documents/learn/bymr-api/examples/../bymr_api/client.py:221, in BYMRClient._make_request(self, method, endpoint, data, params)
#     218             form_data[key] = str(value)
#     219     encoded_data = urlencode(form_data)
# --> 221 response = self.session.request(
#     222     method=method,
#     223     url=url,
#     224     data=encoded_data,
#     225     params=params,
#     226     timeout=self.timeout,
#     227     verify=self.verify_ssl,
#     228     headers=(
#     229         {"Content-Type": "application/x-www-form-urlencoded"}
#     230         if encoded_data
#     231         else None
#     232     ),
#     233 )
#     235 # Handle different status codes
#     236 if response.status_code == 401:
#
# File ~/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/requests/adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File ~/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/Documents/learn/bymr-api/.venv/lib/python3.14/site-packages/urllib3/connection.py:571, in HTTPConnection.getresponse(self)
#     568 _shutdown = getattr(self.sock, "shutdown", None)
#     570 # Get the response from http.client.HTTPConnection
# --> 571 httplib_response = super().getresponse()
#     573 try:
#     574     assert_header_parsing(httplib_response.msg)
#
# File /opt/homebrew/Cellar/python@3.14/3.14.2/Frameworks/Python.framework/Versions/3.14/lib/python3.14/http/client.py:1450, in HTTPConnection.getresponse(self)
#    1448 try:
#    1449     try:
# -> 1450         response.begin()
#    1451     except ConnectionError:
#    1452         self.close()
#
# File /opt/homebrew/Cellar/python@3.14/3.14.2/Frameworks/Python.framework/Versions/3.14/lib/python3.14/http/client.py:336, in HTTPResponse.begin(self)
#     334 # read until we get a non-100 response
#     335 while True:
# --> 336     version, status, reason = self._read_status()
#     337     if status != CONTINUE:
#     338         break
#
# File /opt/homebrew/Cellar/python@3.14/3.14.2/Frameworks/Python.framework/Versions/3.14/lib/python3.14/http/client.py:297, in HTTPResponse._read_status(self)
#     296 def _read_status(self):
# --> 297     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     298     if len(line) > _MAXLINE:
#     299         raise LineTooLong("status line")
#
# File /opt/homebrew/Cellar/python@3.14/3.14.2/Frameworks/Python.framework/Versions/3.14/lib/python3.14/socket.py:725, in SocketIO.readinto(self, b)
#     723     raise OSError("cannot read from timed out object")
#     724 try:
# --> 725     return self._sock.recv_into(b)
#     726 except timeout:
#     727     self._timeout_occurred = True
#
# File /opt/homebrew/Cellar/python@3.14/3.14.2/Frameworks/Python.framework/Versions/3.14/lib/python3.14/ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/homebrew/Cellar/python@3.14/3.14.2/Frameworks/Python.framework/Versions/3.14/lib/python3.14/ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:
